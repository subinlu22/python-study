# %% [markdown]
# <a href="https://colab.research.google.com/github/subinlu22/python-study/blob/main/2026_0329%EC%98%A4%ED%9B%84%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. 평균 구하기: 국어 80, 영어 75, 수학 55점인 학생의 평균 점수를 구하세요.

a = 80
b = 75
c = 55
d=a+b+c
d
# Out:
# 210

# %%
210/3
# Out:
# 70.0

# %%
#2. 나머지와 거듭제곱: 17을 3으로 나눈 나머지의 4제곱을 구하세요.

a = 17/3
a++4
# Out:
# 9.666666666666668

# %%
#3. 주민등록번호 분석: pin = "881120-1068234"에서 성별을 나타내는 숫자 하나만 추출하세요.

pin = "881120-1068234"
pin[7]
# Out:
# '1'

# %%
#4. 문자열 역순: "PYTHON"이라는 문자열을 슬라이싱을 이용해 역순인 "NOHTYP"로 만드세요.


a = "PYTHON"
a= a[5] + a[4] + a[3] +a[2] + a[1] + a[0]
a
# Out:
# 'NOHTYP'

# %%
#5. 전화번호 하이픈 제거: "010-1234-5678"을 "01012345678"로 바꾸세요.


a ="010-1234-5678"

# %%
b = a[0:3]+a[4:8]+a[9:13]
b
# Out:
# '01012345678'

# %%
#6. 도메인 추출: "http://google.com"에서 도메인 이름인 "google"만 뽑아내세요.

a="http://google.com"
b=a[7:13]
b
# Out:
# 'google'

# %%
#7. 문자열 포매팅: 변수 s = "apples", n = 5를 이용해 "I ate 5 apples."를 출력하세요. (f-string 사용)

s = "apples"
n = 5
"I ate %d %s." %(n,s)
# Out:
# 'I ate 5 apples.'

# %%
#8. 문자열 인덱스 찾기: "Python is the best"에서 가장 처음 나오는 't'의 위치를 찾으세요.

a="Python is the best"
a.find("t")
# Out:
# 2

# %%
#9. 문자열 삽입: "abcd" 문자열의 각 문자 사이에 ,를 삽입하여 "a,b,c,d"를 만드세요.

",".join('abcd')
# Out:
# 'a,b,c,d'

# %%
#10. 공백 및 특정 문자 제거: " ,  python.  "에서 양쪽 공백, 쉼표, 마침표를 모두 제거하여 "python"만 남기세요.

a=" ,  python.  "
b=a.strip()
c=b[3:9]
c
# Out:
# 'python'

# %%
#11. 단어 개수 세기: "apple banana apple cherry apple"에서 "apple"이 몇 번 나오는지 구하세요.

a=  "apple banana apple cherry apple"
a.count("apple")
# Out:
# 3

# %%
#12. 단어 교체: "A roaring lion gathers no moss"에서 "lion"을 "stone"으로 바꾸세요.

a="A roaring lion gathers no moss"
a=a.replace("lion", "stone")
a
# Out:
# 'A roaring stone gathers no moss'

# %%
#13. 문자열 나누기: "apple:banana:cherry"를 리스트 형태로 쪼개세요.

a="apple:banana:cherry"
b =a.split(':')
print(b)
# Out:
# ['apple', 'banana', 'cherry']

# %%
#14. 고급 슬라이싱: "12345678"에서 홀수만 뽑아 "1357"을 만드세요.

a = "12345678"
b= a[0]+a[2]+a[4]+a[6]
print(b)
# Out:
# 1357

# %%
#15. 문자열 불변성: "Pithon"을 "Python"으로 바꾸기 위해 슬라이싱과 + 연산을 조합하세요.

a="Pithon"
b= a[0] + 'y' + a[2:6]
print(b)
# Out:
# Python

# %%
#16. 리스트 병합과 정렬: [1, 3, 5]와 [4, 2]를 합친 뒤 내림차순으로 정렬하세요.

a = [1, 3, 5]
b = [4, 2]
c = a + b

c.sort()
c.reverse()
c
# Out:
# [5, 4, 3, 2, 1]

# %%
#17. 중첩 리스트 접근: a = [1, 2, ['a', 'b', ['Life', 'is']]]에서 "Life"만 추출하세요.

a = [1, 2, ['a', 'b', ['Life', 'is']]]
a[2][2][0]
# Out:
# 'Life'

# %%
#18. 리스트 요소 삭제: [1, 2, 3, 1, 2, 3]에서 인덱스 1번부터 3번까지 한 번에 삭제하세요.

a=[1, 2, 3, 1, 2, 3]
del a[1:4]
a
# Out:
# [1, 2, 3]

# %%
#19. 특정 값 삭제: a = [1, 2, 3, 2]에서 첫 번째로 나오는 2만 삭제하세요.

a = [1, 2, 3, 2]
a.remove(2)
a
# Out:
# [1, 3, 2]

# %%
#20. 리스트 마지막 요소 뽑기: a = [1, 2, 3]에서 마지막 요소를 제거하고 그 값을 변수 x에 담으세요.

a = [1, 2, 3]
a.pop()
a
# Out:
# [1, 2]

# %%
#21. 중복 요소 개수: a = [1, 1, 2, 2, 3, 3, 3]에서 숫자 3의 개수를 세세요.

a = [1, 1, 2, 2, 3, 3, 3]
a.count(3)
# Out:
# 3

# %%
#22. 리스트 확장: a = [1, 2]에 [3, 4]를 append가 아닌 방식으로 더해 [1, 2, 3, 4]를 만드세요.

a = [1, 2]
a.extend([3,4])
a
# Out:
# [1, 2, 3, 4]

# %%
#23. 리스트 위치 찾기: ['a', 'b', 'c', 'd']에서 'c'가 몇 번째 인덱스에 있는지 구하세요.

a = ['a', 'b', 'c', 'd']
a.index('c')
# Out:
# 2

# %%
#24. 리스트의 길이와 인덱스: 리스트의 마지막 요소를 len() 함수를 활용하여 인덱싱하세요.
#####
a = ['a', 'b', 'c', 'd']
len(a)
# Out:
# 4

# %%
#25. 리스트 사이값 삽입: [1, 5] 사이에 [2, 3, 4]를 넣어 [1, 2, 3, 4, 5]를 만드세요.

a = [1,5]
a.extend([2,3,4])
a.sort()
a
# Out:
# [1, 2, 3, 4, 5]

# %%
#26. 문자열 리스트 합치기: ['Life', 'is', 'too', 'short']를 공백 한 칸을 두고 하나의 문장으로 합치세요.

a=['Life', 'is', 'too', 'short']
" ".join(a)
# Out:
# 'Life is too short'

# %%
#27. 리스트 비우기: 리스트의 모든 요소를 삭제하여 빈 리스트로 만드세요.

a = [1, 2, 3]
del a[0:]
a
# Out:
# []

# %%
#28. 문자열 리스트 정렬: ['b', 'a', 'c']를 알파벳 순서로 정렬하세요.


a= ['b', 'a', 'c']
a.sort()
a
# Out:
# ['a', 'b', 'c']

# %%
#29. 리스트 슬라이싱 응용: a = [1, 2, 3, 4, 5]에서 [2, 3, 4]를 추출한 뒤 이를 뒤집으세요.

a = [1, 2, 3, 4, 5]
b=a[1:4]
b.reverse()
b
# Out:
# [4, 3, 2]

# %%
#30. 숫자형 변환: 문자열 "123"을 숫자형으로 바꾸고 100을 더하세요.

a = "123"
b=int(a)+100
b
# Out:
# 223
