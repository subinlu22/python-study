# %% [markdown]
# <a href="https://colab.research.google.com/github/subinlu22/python-study/blob/main/0311_%EC%98%A4%EB%8A%98%EC%9D%98_%EB%AF%B8%EC%85%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dic = {"이름":"봉봉", "나이":"29살", "취미":["코딩","물멍","게임"]}
print(dic["나이"])
# Out:
# 29살

# %%
dic["행운의 숫자"]=(1,2,3)
print(dic)
# Out:
# {'이름': '봉봉', '나이': '29살', '취미': ['코딩', '물멍', '게임'], '행운의 숫자': (1, 2, 3)}

# %%
dic = {"이름":"봉봉", "나이":"29살", "취미":["코딩","물멍","게임"]}
print(dic["나이"])
dic["행운의 숫자"]=(1,2,3)
print(dic)
print(dic["이름"][0])
# Out:
# 29살
# {'이름': '봉봉', '나이': '29살', '취미': ['코딩', '물멍', '게임'], '행운의 숫자': (1, 2, 3)}
# 봉

# %%
print("=== 내 프로필 ===")
print("이름:",dic["이름"])
print("나이 :",dic["나이"])
print("취미 :",dic["취미"])
print("행운의 숫자 :",dic["행운의 숫자"])
# Out:
# === 내 프로필 ===
# 이름: 봉봉
# 나이 : 29살
# 취미 : ['코딩', '물멍', '게임']
# 행운의 숫자 : (1, 2, 3)
