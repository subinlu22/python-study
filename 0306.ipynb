# %% [markdown]
# <a href="https://colab.research.google.com/github/subinlu22/python-study/blob/main/0306.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#숫자 %d 문자 %s

print("I eat %s apples." % "five")
# Out:
# I eat five apples.

# %%
number = 3

 "I eat %d apples." % number
# Out:
#   File "/tmp/ipykernel_419/24419586.py", line 3
#     "I eat %d apples." % number
#     ^
# IndentationError: unexpected indent

# %%
#2개 이상의 값 넣기

number = 10
day = "three"
"I ate %d apples. so I was sick for %s days." % (number, day)
'I ate 10 apples. so I was sick for three days.'
# Out:
# 'I ate 10 apples. so I was sick for three days.'

# %%
eval("1+2")
# Out:
# 3

# %%
#원래 퍼센트 에스면 문자열임 근데 숫자를 써도 에러가 안나옴 그냥 문자로 해석해버려서
"I have %s apples" % 3
# Out:
# 'I have 3 apples'

# %%
#원래 퍼센트 에프임
"rate is %s" % 3.234

"rate is %f" % 3.234 #이렇게하면 소숫점 여섯째 자리까지 나옴
"rate is %.2f" % 3.234#이렇게하면 두번째자리까지
# Out:
# 'rate is 3.23'

# %%
 "Error is %d%." % 98  #이렇게하면 오류가남 98%이런식으로 나타내려면 %를 두개 써줘야함
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_419/1464560037.py in <cell line: 0>()
# ----> 1 "Error is %d%." % 98  #이렇게하면 오류가남 98%이런식으로 나타내려면 %를 두개 써줘야함
#       2
#       3 "Error is %d%%." % 98
#
# ValueError: incomplete format

# %%
 "Error is %d%%." % 98
# Out:
# 'Error is 98%.'

# %%
#중간 퍼센트를 기준으로 왼쪽(열자리를 잡으세요) 오른쪽 정렬방식으로 하이를 쓰세요.오른쪽 정렬방식
#왼쪽정렬은 -를 붙이기

"%10s" % "hi"
"%-10sjane." % 'hi'
# Out:
# 'hi        jane.'

# %%
#보통 0빼고씀
"%0.4f" % 3.42134234

"%.4f" % 3.42134234
# Out:
# '3.4213'

# %%
#프린트를 써서 문장출력을하지않고 굳이 퍼센트를 써서 대입하는 이유
#번거롭지않고 쉽게 수치를 바꾸기 위해서

# %%
#영어단어뒤에 소괄호가 나오면 대부분 함수

"I eat {0} apples".format(3)
# Out:
# 'I eat 3 apples'

# %%
"I eat {0} apples".format("five")
# Out:
# 'I eat five apples'

# %%
#포맷값 두개이상 함수 넣기
#0번과 1번 순서대로 들어감

number = 10
day = "three"
"I ate {0} apples. so I was sick for {1} days.".format(number, day)
#괄호안 숫자 차이
"I ate {1} apples. so I was sick for {0} days.".format(number, day)
# Out:
# 'I ate three apples. so I was sick for 10 days.'

# %%
#이름으로 넣기,잘 사용하지않

"I ate {number} apples. so I was sick for {day} days.".format(number=10, day=3)
# Out:
# 'I ate 10 apples. so I was sick for 3 days.'

# %%
#인덱스와 이름을 혼용해서 넣기

"I ate {0} apples. so I was sick for {day} days.".format(10, day=3)
# Out:
# 'I ate 10 apples. so I was sick for 3 days.'

# %%
#왼쪽 정렬,열자리를 확보한다음에 왼쪽으로 정렬해라

"{0:<10}".format("hi")
# Out:
# 'hi        '

# %%
"{0:>10}".format("hi")
# Out:
# '        hi'

# %%
"{0:^10}".format("hi")
# Out:
# '    hi    '

# %%
#공백채우기
"{0:=^10}".format("hi")
# Out:
# '====hi===='

# %%
"{0:$^10}".format("hi")
# Out:
# '$$$$hi$$$$'

# %%
y = 3.42134234
"{0:0.4f}".format(y) #.4f소숫점 넷째자리까지
"{0:10.4f}".format(y)#앞 열자리 확보하고싶을때
# Out:
# '    3.4213'

# %%
#f문자열 포매팅,많이쓰임

name = '홍길동'
age = 30
print(f'나의 이름은 {name}입니다. 나이는 {age}입니다.')
#문자열 속에 있는 변수 값 또는 수식 결과를 출력하고자 하는 경우 f 포매팅을 이용
print(f'나의 이름은 {name}입니다. 나이는 {age+5}입니다.')
# Out:
# 나의 이름은 홍길동입니다. 나이는 30입니다.
# 나의 이름은 홍길동입니다. 나이는 35입니다.

# %%
d = {'name':'홍길동', 'age':30} #중가로는 딕셔너리 라고함. 딕셔너리 = {키:값, ...}
f'나의 이름은 {d["name"]}입니다. 나이는 {d["age"]}입니다.'
# Out:
# '나의 이름은 홍길동입니다. 나이는 30입니다.'

# %%
y = 3.42134234
f'{y:0.4f}'
# Out:
# '3.4213'

# %%
#문자 개수 세기

a = "hobby"
a.count('b')
# Out:
# 2

# %%
#한번에 하나만 찾을수있음,제일 앞 첫번

a = "Python is the best choice"
a.find('b')
# Out:
# 14

# %%
a = "Python is the best choice"
a.find('b',10)#10번부터 찾기

a.find('k') #없는 문자를 찾으려고 시도하면 -1이 나옴

a.find('is') #이 단어가 시작되는 위치가 나옴
# Out:
# 7

# %%
#find랑 비슷한 index함수
a = "Life is too short"
a.index('t') #t의 위치번호
a.index('z') #index함수는 검색이안될때 -1이 아닌 에러가 난다.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_419/2195866805.py in <cell line: 0>()
#       2 a = "Life is too short"
#       3 a.index('t') #t의 위치번호
# ----> 4 a.index('z')
#
# ValueError: substring not found

# %%
#join함수, 문자 사이사이에 콤마를 삽입.

",".join('abcd')
# Out:
# 'a,b,c,d'

# %%
joined = ",".join('abcd')

# %%
joined.split(",")
# Out:
# ['a', 'b', 'c', 'd']

# %%
#소문자를 대문자로 바꾸기

a = "hi"
a.upper()
# Out:
# 'HI'

# %%
#대문자를 문자로 바꾸기

a = "HI"
a.lower()
# Out:
# 'hi'

# %%
#왼쪽 공백지우기

a= " hi "
a.lstrip()
# Out:
# 'hi '

# %%
#오른쪽 공백 제거

a= " hi "
a.rstrip()
# Out:
# ' hi'

# %%
#양쪽 공백 제거

a = " hi "
a.strip()
# Out:
# 'hi'

# %%
#문자열 바꾸기,사용빈도 높음문자열 바꾸기,사용빈도 높음

a = "Life is too short"
a.replace("Life", "Your leg")
# Out:
# 'Your leg is too short'

# %%
w_news="""
지금 서울 남산 보시면 눈이 날리고 있습니다.

오늘 오전부터 밤사이 중부지방을 중심으로 다시 비나 눈이 오는 곳이 있겠는데요.

앞으로 예상 강수량은 5밀리미터 정도고, 예상되는 눈의 양은 강원 산지에 1에서 5, 경기 내륙과 강원 내륙, 충북 북부, 전북 동부에 1센티미터 안팎입니다.

새벽에 북서풍을 타고 국외 미세먼지가 들어와 아침에 수도권을 시작으로 공기가 탁해지겠습니다.

오늘 초미세먼지 농도는 수도권은 종일 '나쁨'인데요.

이 미세먼지가 점차 남동진하면서 오후엔 남부지방까지 확산하겠습니다.

그러나 밤부터 북쪽에서 찬 공기가 몰려와 중서부 해안부터 먼지는 점차 걷히겠습니다.

비나 눈이 그친 뒤 주말엔 영하권 추위가 찾아오겠습니다.

오늘 한낮엔 어제보다 최대 10도 정도나 낮겠고, 평년보다도 낮아지겠습니다.

주말인 내일과 모레 일요일 아침은 서울이 영하 3도까지 떨어지겠습니다.

여기에 바람까지 강하게 불어 실제 몸으로 느껴지는 추위는 더 심하겠습니다.

오늘은 전국이 대체로 흐리겠습니다.

낮 기온은 서울이 5도, 청주, 대전 7, 광주와 안동은 9도밖에 되지 않겠습니다.

바다의 물결은 풍랑주의보가 내려진 동해 중부 먼바다에서 최고 5미터로 매우 높게 일겠습니다.

날씨 전해드렸습니다.

이설아 기상캐스터/그래픽:한세희"""

# %%
print(w_news)
# Out:
# 지금 서울 남산 보시면 눈이 날리고 있습니다.
#
# 오늘 오전부터 밤사이 중부지방을 중심으로 다시 비나 눈이 오는 곳이 있겠는데요.
#
# 앞으로 예상 강수량은 5밀리미터 정도고, 예상되는 눈의 양은 강원 산지에 1에서 5, 경기 내륙과 강원 내륙, 충북 북부, 전북 동부에 1센티미터 안팎입니다.
#
# 새벽에 북서풍을 타고 국외 미세먼지가 들어와 아침에 수도권을 시작으로 공기가 탁해지겠습니다.
#
# 오늘 초미세먼지 농도는 수도권은 종일 '나쁨'인데요.
#
# 이 미세먼지가 점차 남동진하면서 오후엔 남부지방까지 확산하겠습니다.
#
# 그러나 밤부터 북쪽에서 찬 공기가 몰려와 중서부 해안부터 먼지는 점차 걷히겠습니다.
#
# 비나 눈이 그친 뒤 주말엔 영하권 추위가 찾아오겠습니다.
#
# 오늘 한낮엔 어제보다 최대 10도 정도나 낮겠고, 평년보다도 낮아지겠습니다.
#
# 주말인 내일과 모레 일요일 아침은 서울이 영하 3도까지 떨어지겠습니다.
#
# 여기에 바람까지 강하게 불어 실제 몸으로 느껴지는 추위는 더 심하겠습니다.
#
# 오늘은 전국이 대체로 흐리겠습니다.
#
# 낮 기온은 서울이 5도, 청주, 대전 7, 광주와 안동은 9도밖에 되지 않겠습니다.
#
# 바다의 물결은 풍랑주의보가 내려진 동해 중부 먼바다에서 최고 5미터로 매우 높게 일겠습니다.
#
# 날씨 전해드렸습니다.
#
# 이설아 기상캐스터/그래픽:한세희

# %%
#w_news에 저장된 '오늘' 단어를 모두 '투데이'로 치환하시오.

#문자열 바꾸기,사용빈도 높음문자열 바꾸기,사용빈도 높음

print(w_news.replace("오늘", "투데이",2))
w_news=w_news.replace("오늘", "투데이",2)#바꾼걸 저장하기위해서 지정을 해줘야함 (w_news=)
# Out:
# 지금 서울 남산 보시면 눈이 날리고 있습니다.
#
# 투데이 오전부터 밤사이 중부지방을 중심으로 다시 비나 눈이 오는 곳이 있겠는데요.
#
# 앞으로 예상 강수량은 5밀리미터 정도고, 예상되는 눈의 양은 강원 산지에 1에서 5, 경기 내륙과 강원 내륙, 충북 북부, 전북 동부에 1센티미터 안팎입니다.
#
# 새벽에 북서풍을 타고 국외 미세먼지가 들어와 아침에 수도권을 시작으로 공기가 탁해지겠습니다.
#
# 투데이 초미세먼지 농도는 수도권은 종일 '나쁨'인데요.
#
# 이 미세먼지가 점차 남동진하면서 오후엔 남부지방까지 확산하겠습니다.
#
# 그러나 밤부터 북쪽에서 찬 공기가 몰려와 중서부 해안부터 먼지는 점차 걷히겠습니다.
#
# 비나 눈이 그친 뒤 주말엔 영하권 추위가 찾아오겠습니다.
#
# 오늘 한낮엔 어제보다 최대 10도 정도나 낮겠고, 평년보다도 낮아지겠습니다.
#
# 주말인 내일과 모레 일요일 아침은 서울이 영하 3도까지 떨어지겠습니다.
#
# 여기에 바람까지 강하게 불어 실제 몸으로 느껴지는 추위는 더 심하겠습니다.
#
# 오늘은 전국이 대체로 흐리겠습니다.
#
# 낮 기온은 서울이 5도, 청주, 대전 7, 광주와 안동은 9도밖에 되지 않겠습니다.
#
# 바다의 물결은 풍랑주의보가 내려진 동해 중부 먼바다에서 최고 5미터로 매우 높게 일겠습니다.
#
# 날씨 전해드렸습니다.
#
# 이설아 기상캐스터/그래픽:한세희

# %%
print(w_news)
# Out:
# 지금 서울 남산 보시면 눈이 날리고 있습니다.
#
# 투데이 오전부터 밤사이 중부지방을 중심으로 다시 비나 눈이 오는 곳이 있겠는데요.
#
# 앞으로 예상 강수량은 5밀리미터 정도고, 예상되는 눈의 양은 강원 산지에 1에서 5, 경기 내륙과 강원 내륙, 충북 북부, 전북 동부에 1센티미터 안팎입니다.
#
# 새벽에 북서풍을 타고 국외 미세먼지가 들어와 아침에 수도권을 시작으로 공기가 탁해지겠습니다.
#
# 투데이 초미세먼지 농도는 수도권은 종일 '나쁨'인데요.
#
# 이 미세먼지가 점차 남동진하면서 오후엔 남부지방까지 확산하겠습니다.
#
# 그러나 밤부터 북쪽에서 찬 공기가 몰려와 중서부 해안부터 먼지는 점차 걷히겠습니다.
#
# 비나 눈이 그친 뒤 주말엔 영하권 추위가 찾아오겠습니다.
#
# 오늘 한낮엔 어제보다 최대 10도 정도나 낮겠고, 평년보다도 낮아지겠습니다.
#
# 주말인 내일과 모레 일요일 아침은 서울이 영하 3도까지 떨어지겠습니다.
#
# 여기에 바람까지 강하게 불어 실제 몸으로 느껴지는 추위는 더 심하겠습니다.
#
# 오늘은 전국이 대체로 흐리겠습니다.
#
# 낮 기온은 서울이 5도, 청주, 대전 7, 광주와 안동은 9도밖에 되지 않겠습니다.
#
# 바다의 물결은 풍랑주의보가 내려진 동해 중부 먼바다에서 최고 5미터로 매우 높게 일겠습니다.
#
# 날씨 전해드렸습니다.
#
# 이설아 기상캐스터/그래픽:한세희

# %%
a = "Life is too short"
a.split()
# Out:
# ['Life', 'is', 'too', 'short']

# %%
",".join(['a', 'b', 'c', 'd'])
# Out:
# 'a,b,c,d'

# %%
"".join(['a', 'b', 'c', 'd'])
# Out:
# 'abcd'

# %%
",".join(['abcd'])
# Out:
# 'abcd'

# %%
a = "Life is too short"
a.split() #문자열을 공백으로 분리한다
a.split("i")#i를 기준으로 분리
# Out:
# ['L', 'fe ', 's too short']

# %%
#문자열이 알파벳으로만 구성되어 있는지 확인하기 - isalpha
#문자열이 숫자로만 구성되어 있는지 확인하기 - isdigit
#문자열이 특정 문자(열)로 시작하는지 확인하기 - startswith
#문자열이 특정 문자(열)로 끝나는지 확인하기 - endswith


#리스트안에 리스트나 딕셔너리도 다 저장가능
#대괄호[]면 리스트 소괄호()는 튜플 중괄호{:} 딕셔너리 {,,} 집합
#리스트에있는 자료들은 콤마로 구분한다.
#대괄호 안 대괄호는 하나로 봐야한다  e = [1, 2, ['Life', 'is']] 이경우 3개의 리스트임

# %%
#리스트의 인덱싱

a = [1, 2, 3]
a
# Out:
# [1, 2, 3]

# %%
a[0]
# Out:
# 1

# %%
a[0] + a[2]
# Out:
# 4

# %%
a = [1, 2, 3, ['a', 'b', 'c']]
a
a[3]
a[-1]
a[3][1]#리스트안 리스트에있는걸 사용할때. 에이안에있는 3번이 먼저 실행된후 그 다음에 1번째가 추출되는것
# Out:
# 'b'

# %%
#삼중 리스트에서 인덱싱하기
a = [1, 2, ['a', 'b', ['Life', 'is']]]
a[2]
a[2][2]
a[2][2][0]
# Out:
# 'Life'

# %%
a = [1, 2, 3, 4, 5]
a[0:2] #0번에서 1번까지
# Out:
# [1, 2]

# %%
a = "12345"
a[0:2]
# Out:
# '12'

# %%
a = [1, 2, 3, ['a', 'b', 'c'], 4, 5]
a[2:5]
a[3][:2]
# Out:
# ['a', 'b']

# %%
a = [1, 2, 3]
b = [4, 5, 6]
a + b
#리스트 사이에서 +는 2개의 리스트를 합치는 기능을 한다.
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a = [1, 2, 3]
a * 3
#리스트 반복하기(*)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
a = [1, 2, 3]
len(a)
# Out:
# 3

# %%
a = [1, 2, 3]
#a[2] + "hi"#더해져 나올거같지만 리스트와 문자열은 더할수가 없다.
#숫자와 문자열을 더해서 '3hi'를 만들고 싶다면 다음처럼 숫자 3을 문자 '3'으로 바꾸어야 한다.
str(a[2]) + "hi" #str은 정수나 실수를 문자열로 바꾸어 주는 파이썬의 내장 함수이다.
# Out:
# '3hi'

# %%
#리스트의 수정과 삭제

a = [1, 2, 3]
a[2] = 4
a
# Out:
# [1, 2, 4]

# %%
#del로 리스트 요소 삭제하기

a = [1, 2, 3]
del a[1]
a
# Out:
# [1, 3]

# %%
a = [1, 2, 3, 4, 5]
del a[2:]#2번부터 다 지워짐,델은 저장을 안해도 값이 바뀌어버림.델과 리무브를 제일 많이씀 팝도 쓰이긴 쓰임 다 같은 기능.
a
# Out:
# [1, 2]

# %%
a = [1, 2, 3]
a.append(4)
#a.append([5, 6]) #리스트안에 리스트로 넣는방법
#하지만 괄호없이 넣고싶을땐?
a.extend([5, 6]) #생각보다 종종 씀
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#리스트 정렬 - sort 생각보다 종종씀

a = [1, 4, 3, 2]
a.sort() #inplace 함수
a
# Out:
# [1, 2, 3, 4]

# %%
a = ['a', 'c', 'b']
a.sort()
a
# Out:
# ['a', 'b', 'c']

# %%
a = ['a', 'c', 'b']
a.sort(reverse=True) #내름차순 정렬
a
# Out:
# ['c', 'b', 'a']

# %%
#리스트 뒤집기 - reverse

a = ['a', 'c', 'b']
a.reverse()
a
# Out:
# ['b', 'c', 'a']

# %%
#연습할때 안보고 코딩해보기.

# %%
x=[5,3,1,2,4]
x.sort()
x.reverse()
x
# Out:
# [5, 4, 3, 2, 1]

# %%
#인덱스 반환 - index

a = [1, 2, 3]
a.index(3)
# Out:
# 2

# %%
#리스트에 요소 삽입 - insert,insert(a, b)는 리스트의 a번째 위치에 b를 삽입하는 함수이다.

a = [1, 2, 3]
a.insert(0, 4)
a
#위 예는 0번째 자리, 즉 첫 번째 요소인 a[0] 위치에 값 4를 삽입하라는 뜻이다.
# Out:
# [4, 1, 2, 3]

# %%
#들여쓰기 하면안됨. 하는 경우도 있음.지금은 들여쓰기를 막 하지말고 이어서 붙여서 하기.

# %%
a
# Out:
# [4, 1, 2, 3]

# %%
a.insert(3, 5)

# %%
a
# Out:
# [4, 1, 2, 5, 5, 5, 5, 3]

# %%
#리스트 요소 제거 - remove

a = [1, 2, 3, 1, 2, 3]
a.remove(3)
a
# Out:
# [1, 2, 1, 2, 3]

# %%
#리스트 요소 꺼내기 - pop
a = [1, 2, 3]
a.pop()
# Out:
# 3

# %%
a
# Out:
# [1, 2]

# %%
a = [1, 2, 3]
a.pop(1)#pop(x)는 리스트의 x번째 요소를 반환하고 그 요소는 삭제한다.
# Out:
# 2

# %%
a
# Out:
# [1, 3]

# %%
#리스트에 포함된 요소 x의 개수 세기 - count
a = [1, 2, 3, 1]
a.count(1)
# Out:
# 2

# %%
#리스트 확장 - extend
#extend(x)에서 x에는 리스트만 올 수 있으며 원래의 a 리스트에 x 리스트를 더하게 된다.
#리스트는 사용빈도가 높음

a = [1, 2, 3]
a.extend([4, 5])
a
b = [6, 7]
a.extend(b)
a
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
#문제 1. 리스트 합치기와 정렬
다음 두 리스트를 합쳐서 하나의 리스트 c를 만들고, 숫자가 큰 순서대로(내림차순) 정렬하는 코드를 작성하세요.

a = [1, 5, 2]

b = [3, 4]

원하는 결과: [5, 4, 3, 2, 1]

문제 2. 중첩 리스트에서 값 수정하기
아래 리스트 life에서 'Life'라는 글자를 'Coding'으로 바꾸는 코드를 작성하세요. (인덱싱을 사용하세요!)

life = [1, 2, ['Life', 'is', 'short']]

원하는 결과: [1, 2, ['Coding', 'is', 'short']]

문제 3. 리스트 요소 삭제와 추가
리스트 fruit = ['apple', 'banana', 'cherry']가 있습니다. 이 리스트에서 'banana'를 삭제하고, 그 자리에 'grape'를 넣는 코드를 작성하세요. (인덱싱 등 배운 방법을 자유롭게 활용해 보세요.)

원하는 결과: ['apple', 'grape', 'cherry']

# %%
a = [1, 5, 2]
b = [3, 4]
c=a+b

# %%
c.sort()
c
# Out:
# [1, 2, 3, 4, 5]

# %%
life = [1, 2, ['Life', 'is', 'short']]
life[2][0] = 'Coding'
life
# Out:
# [1, 2, ['Coding', 'is', 'short']]

# %%
fruit = ['apple', 'banana', 'cherry']
del fruit[1]
fruit
# Out:
# ['apple', 'cherry']

# %%
fruit.insert(1,'grape')
fruit
# Out:
# ['apple', 'grape', 'cherry']
