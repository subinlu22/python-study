# %% [markdown]
# <a href="https://colab.research.google.com/github/subinlu22/python-study/blob/main/2026_0305.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 1.2
a = -3.45

# %%
a
# Out:
# -3.45

# %%
print (a)
# Out:
# -3.45

# %%
x=1
y=2
print(x)
print(y)
# Out:
# 1
# 2

# %%
2**5
# Out:
# 32

# %%
2**1000
# Out:
# 

# %%
7 % 3
# Out:
# 1

# %%
a=1
#a=a+1
print(a)
# Out:
# 1

# %%
#축약형
b=1
#b+=1
#b-=1
b*=2
print(b)
# Out:
# 2

# %%
#에러
#만약 문자 p를 저장하고싶을때 작은 따옴표나 큰 따옴표
#x=p
x="p"

# %%
x="python"

# %%
#여러줄에 걸쳐서 문자표현을 하면 따옴표를 세개씩

x="""Life is too short,
You need python"""

# %%
#빨간색 밑줄이 나오면 에러인거임
#문자열 안에 작은 따옴표를 넣어야한다면 바깥쪽은 큰따옴표를 써서 헷갈리지 않게
food = "Python's favorite food is perl"

# %%
#큰따옴표랑 작은 따옴표의 구분을 잘 해야함

say = '"Python is very easy." he says.'

# %%
print(say)
# Out:
# "Python is very easy." he says.

# %%
#따옴표까지 다 출력하고싶으면 역슬래시를 쓰면됨
food = 'Python\'s favorite food is perl'

# %%
print(food)
# Out:
# Python's favorite food is perl

# %%
#문자열 더해서 연결하기

head = "Python"
tail = " is fun!"
print(head + tail)
# Out:
# Python is fun!

# %%
#문자열 곱하기
a = "python"
print(a*10)
# Out:
# pythonpythonpythonpythonpythonpythonpythonpythonpythonpython

# %%
print("ㅋ"*100)
# Out:
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ

# %%
print("=" * 50)
print("My Program")
print("=" * 50)
# Out:
# ...
# My Program
# ...

# %%
a = "Life is too short"
len(a)#길이의 약자 len,공백문자 포함길이
# Out:
# 17

# %%
a = "Life is too short, You need Python"

# %%
#프린트를 안써도 출력가능은 함,그래도 프린트 쓰는게 정석적인 출력방법
#인덱스(문자의 위치)[],인덱스는 0번부터 시작함

a[3]
# Out:
# 'e'

# %%
print(a[3])
# Out:
# e

# %%
a[3]
a[-2]#마이너스가 붙으면 뒤에서 몇번째 문자인지
# Out:
# 'o'

# %%
a = "Life is too short, You need Python"
a[0] + a[1]
#따옴표없이 뽑으려면 프린트문 써서 출력
a[0:4]#a에 0번부터 시작해서 4번 전까지 3번까지라는 소리
# Out:
# 'Life'

# %%
a[19:]#19번부터 마지막끝까지
a[:7]#0~6까지
a[:]#처음~끝
a#처음~끝
# Out:
# 'Life is too short, You need Python'

# %%
a[19:-7]#-7앞까지 영역설정
# Out:
# 'You need'

# %%
x= "분당융합기술교육원"

# %%
len(x)
# Out:
# 9

# %%
x[3:5]
# Out:
# '합기'

# %%
x[:len(x)-5] # x[:4]
# Out:
# '분당융합'

# %%
#셀의 위치보다 실행순서가 중요하다.셀 안에서는 순서대로 해야함.
print(k)
# Out:
# 5

# %%
k=5

# %%
#포매팅 문자열 %d 자리에 숫자 3을 넣는것. 형식지정.
w=5
print("I eat %d apples." % w)
# Out:
# I eat 5 apples.
