# %% [markdown]
# <a href="https://colab.research.google.com/github/subinlu22/python-study/blob/main/2026_0309.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#02-4 튜플 자료형
#리스트는 요솟값의 생성, 삭제, 수정이 가능하지만, 튜플은 요솟값을 바꿀 수 없다.
#리스트는 [], 튜플은 ()으로 둘러싼다.
#리스트와 비슷, 1개의 요소만을 가질 때는 요소 뒤에 쉼표(,)를 반드시 붙여야 한다는 것
#소괄호 생략 가능, 튜플안에 튜플저장 가능

t1 = (1, 2, 'a', 'b')

# %%
del t1[0]

#튜플은 삭제를 지원하지 않는다.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_375/2661958664.py in <cell line: 0>()
# ----> 1 del t1[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
t1 = [1, 2, 'a', 'b'] #리스트로 바꾸면 삭제가 됨

# %%
del t1[0]

# %%
t1
# Out:
# [2, 'a', 'b']

# %%
t1 = (1, 2, 'a', 'b')

# %%
t1[0]
#리스트와같이 슬라이싱 인덱싱 더하기 다 가능함.
#데이터 변경이나 삭제가 되면 안되는것은 튜플을 사용하는게 유용함.
#변경작업이 빈번하면 리스트
# Out:
# 1

# %%
t1 = (1, 2, 'a', 'b')
t2 = (3, 4)
t3 = t1 + t2
t3
# Out:
# (1, 2, 'a', 'b', 3, 4)

# %%
t2 = (3, 4)
t3 = t2 * 3
t3
# Out:
# (3, 4, 3, 4, 3, 4)

# %%
t1 = (1, 2, 'a', 'b')
len(t1)
#튜플은 요솟값을 변경할 수 없기 때문에 sort, insert, remove, pop과 같은 메서드가 없다.
# Out:
# 4

# %%
#딕셔너리 자료형 중요
#딕셔너리는 Key와 Value를 한 쌍으로 가지는 자료형.
#딕셔너리는 리스트나 튜플처럼 순차적으로(sequential) 해당 요솟값을 구하지 않고 Key를 통해 Value를 얻는다.

dic = {'name': 'pey', 'phone': '010-9999-1234', 'birth': '1118'} #이 안에는 자료가 3개있는것 한쌍씩
dic
# Out:
# {'name': 'pey', 'phone': '010-9999-1234', 'birth': '1118'}

# %%
len(dic)
# Out:
# 3

# %%
person=['홍길동',25,170]
person[1]
# Out:
# 25

# %%
person_dict={'이름':'홍길동','나이':25,'키':170}

# %%
#딕셔너리 쌍 추가하기

a = {1: 'a'}
a[2] = 'b'

# %%
a
# Out:
# {1: 'a', 2: 'b'}

# %%
a['name'] = 'pey'
a
# Out:
# {1: 'a', 2: 'b', 'name': 'pey'}

# %%
a[3] = [1, 2, 3]
a
# Out:
# {1: 'a', 2: 'b', 'name': 'pey', 3: [1, 2, 3]}

# %%
a['name'] = 'pey'
a
# Out:
# {1: 'a', 2: 'b', 'name': 'pey', 3: [1, 2, 3]}

# %%
del a[1]#del a[key]처럼 사용하면 지정한 Key에 해당하는 {Key: Value} 쌍이 삭제된다.
a
# Out:
# {2: 'b', 'name': 'pey', 3: [1, 2, 3]}

# %%
dic={"김연아": "피겨스케이팅", "류현진": "야구", "손흥민": "축구", "귀도": "파이썬"}
dic['김연아']
# Out:
# '피겨스케이팅'

# %%
#딕셔너리 만들 때 주의할 사항
#딕셔너리에서 Key는 고유한 값이므로 중복되는 Key 값을 설정하면 하나를 제외한 나머지 것들이 모두 무시된다.
#다음 예에서 볼 수 있듯이 동일한 Key가 2개 존재할 경우, 1: 'a' 쌍이 무시된다.

a = {1:'a', 1:'b'}
a

#Key에 리스트는 쓸 수 없다는 것
# Out:
# {1: 'b'}

# %%
list(a.keys())
# Out:
# [1]

# %%
a = {'name': 'pey', 'phone': '010-9999-1234', 'birth': '1118'}
a.keys()
# Out:
# dict_keys(['name', 'phone', 'birth'])

# %%
a.values()
# Out:
# dict_values(['pey', '010-9999-1234', '1118'])

# %%
list(a.keys())
# Out:
# ['name', 'phone', 'birth']

# %%
a.items() #items 함수는 Key와 Value의 쌍을 튜플로 묶은 값을 dict_items 객체로 반환한다.
# Out:
# dict_items([('name', 'pey'), ('phone', '010-9999-1234'), ('birth', '1118')])

# %%
a.clear() #clear 함수는 딕셔너리 안의 모든 요소를 삭제한다.
a
#빈 리스트를 [], 빈 튜플을 ()로 표현하는 것과 마찬가지로 빈 딕셔너리도 {}로 표현한다.
# Out:
# {}

# %%
a = {'name':'pey', 'phone':'010-9999-1234', 'birth': '1118'}

# %%
a
#아래 두개의 결과값은 같다.
a.get('name')
a['name']
# Out:
# 'pey'

# %%
a.get('nokey', '정보없음')
#딕셔너리 a에는 'nokey'에 해당하는 Key가 없다. 따라서 디폴트 값인 '정보없음'을 반환한다.
#오류메세지가 안나오고 안정적으로 사용가
# Out:
# '정보없음'

# %%
a = {'name':'pey', 'phone':'010-9999-1234', 'birth': '1118'}
'name' in a
#있으면 트루 없으면 펄스
# Out:
# True

# %%
a.pop('phone') #팝은 키의값 꺼내지면서 지워짐
# Out:
# '010-9999-1234'

# %%
a #팝은 키의값 꺼내지면서 지워짐
# Out:
# {'name': 'pey', 'birth': '1118'}

# %%
a['phone'] = '010-1234-5678'
print(a)

# %%
movies = {
    'The Shawshank Redemption': {
        'genre': 'Drama',
        'director': 'Frank Darabont',
        'year': 1994,
        'rating': 9.3
    },
    'The Godfather': {
        'genre': 'Crime, Drama',
        'director': 'Francis Ford Coppola',
        'year': 1972,
        'rating': 9.2
    },
    'The Dark Knight': {
        'genre': 'Action, Crime, Drama',
        'director': 'Christopher Nolan',
        'year': 2008,
        'rating': 9.0
    },
    'Pulp Fiction': {
        'genre': 'Crime, Drama',
        'director': 'Quentin Tarantino',
        'year': 1994,
        'rating': 8.9
    },
    'Forrest Gump': {
        'genre': 'Drama, Romance',
        'director': 'Robert Zemeckis',
        'year': 1994,
        'rating': 8.8
    }
}

print(movies)
# Out:
# {'The Shawshank Redemption': {'genre': 'Drama', 'director': 'Frank Darabont', 'year': 1994, 'rating': 9.3}, 'The Godfather': {'genre': 'Crime, Drama', 'director': 'Francis Ford Coppola', 'year': 1972, 'rating': 9.2}, 'The Dark Knight': {'genre': 'Action, Crime, Drama', 'director': 'Christopher Nolan', 'year': 2008, 'rating': 9.0}, 'Pulp Fiction': {'genre': 'Crime, Drama', 'director': 'Quentin Tarantino', 'year': 1994, 'rating': 8.9}, 'Forrest Gump': {'genre': 'Drama, Romance', 'director': 'Robert Zemeckis', 'year': 1994, 'rating': 8.8}}

# %%
inventory={'메론':5000,'수박':12000,'참외':3000}
inventory['수박']
# Out:
# 12000

# %%
inventory['포도']=7000

# %%
inventory
# Out:
# {'수박': 12000, '참외': 3000, '포도': 7000}

# %%
del inventory['메론']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_375/901315146.py in <cell line: 0>()
# ----> 1 del inventory['메론']
#
# KeyError: '메론'

# %%
inventory['메론']=5500

# %%
inventory
# Out:
# {'수박': 12000, '참외': 3000, '포도': 7000, '메론': 5500}

# %%
inventory.get('사과',0)
# Out:
# 0
